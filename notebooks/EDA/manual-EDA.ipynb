# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading Data
PATH = "../../data/featured-data.csv"
df = pd.read_csv(PATH)
print(df.head())
# Out:
#    Marital status  Daytime/evening attendance\t  Previous qualification  \
# 0               1                             1                       1
# 1               1                             1                       1
# 2               1                             1                       1
# 3               1                             1                       1
# 4               2                             0                       1
#
#    Previous qualification (grade)  Admission grade  Displaced  \
# 0                           122.0            127.3          1
# 1                           160.0            142.5          1
# 2                           122.0            124.8          1
# 3                           122.0            119.6          1
# 4                           100.0            141.5          0
#
#    Educational special needs  Debtor  Tuition fees up to date  Gender  \
# 0                          0       0                        1       1
# 1                          0       0                        0       1
# 2                          0       0                        0       1
# 3                          0       0                        1       0
# 4                          0       0                        1       0
#
#    Scholarship holder  Age at enrollment  Curricular units 1st sem (approved)  \
# 0                   0                 20                                    0
# 1                   0                 19                                    6
# 2                   0                 19                                    0
# 3                   0                 20                                    6
# 4                   0                 45                                    5
#
#    Curricular units 1st sem (grade)  Curricular units 2nd sem (approved)  \
# 0                          0.000000                                    0
# 1                         14.000000                                    6
# 2                          0.000000                                    0
# 3                         13.428571                                    5
# 4                         12.333333                                    6
#
#    Curricular units 2nd sem (grade)  \
# 0                          0.000000
# 1                         13.666667
# 2                          0.000000
# 3                         12.400000
# 4                         13.000000
#
#    Curricular units 2nd sem (without evaluations)  Target
# 0                                               0       0
# 1                                               0       1
# 2                                               0       0
# 3                                               0       1
# 4                                               0       1

# %%
# Data Exploration
print(df.shape)
print(df.info())
# Out:
# (3630, 18)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3630 entries, 0 to 3629
# Data columns (total 18 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  3630 non-null   int64
#  1   Daytime/evening attendance	                     3630 non-null   int64
#  2   Previous qualification                          3630 non-null   int64
#  3   Previous qualification (grade)                  3630 non-null   float64
#  4   Admission grade                                 3630 non-null   float64
#  5   Displaced                                       3630 non-null   int64
#  6   Educational special needs                       3630 non-null   int64
#  7   Debtor                                          3630 non-null   int64
#  8   Tuition fees up to date                         3630 non-null   int64
#  9   Gender                                          3630 non-null   int64
#  10  Scholarship holder                              3630 non-null   int64
#  11  Age at enrollment                               3630 non-null   int64
#  12  Curricular units 1st sem (approved)             3630 non-null   int64
#  13  Curricular units 1st sem (grade)                3630 non-null   float64
#  14  Curricular units 2nd sem (approved)             3630 non-null   int64
#  15  Curricular units 2nd sem (grade)                3630 non-null   float64
#  16  Curricular units 2nd sem (without evaluations)  3630 non-null   int64
#  17  Target                                          3630 non-null   int64
# dtypes: float64(4), int64(14)
# memory usage: 510.6 KB
# None

# %%
# Missing Values
missing = df.isnull().sum()
missing[missing > 0].sort_values(ascending=False)

# No missing values found
# Out:
# Series([], dtype: int64)

# %%
# Duplicate Rows
duplicates = df.duplicated().sum()
print("Duplicate rows:", duplicates)

# No duplicate rows found
# Out:
# Duplicate rows: 1

# %%
# Statistical Summary
df.describe()
# Out:
#        Marital status  Daytime/evening attendance\t  Previous qualification  \
# count     3630.000000                   3630.000000             3630.000000
# mean         1.184298                      0.887603                4.532231
# std          0.613009                      0.315897               10.024134
# min          1.000000                      0.000000                1.000000
# 25%          1.000000                      1.000000                1.000000
# 50%          1.000000                      1.000000                1.000000
# 75%          1.000000                      1.000000                1.000000
# max          6.000000                      1.000000               43.000000
#
#        Previous qualification (grade)  Admission grade    Displaced  \
# count                     3630.000000      3630.000000  3630.000000
# mean                       132.920606       127.293939     0.549036
# std                         13.238373        14.611295     0.497658
# min                         95.000000        95.000000     0.000000
# 25%                        125.000000       118.000000     0.000000
# 50%                        133.100000       126.500000     1.000000
# 75%                        140.000000       135.100000     1.000000
# max                        190.000000       190.000000     1.000000
#
#        Educational special needs       Debtor  Tuition fees up to date  \
# count                3630.000000  3630.000000              3630.000000
# mean                    0.011019     0.113774                 0.866116
# std                     0.104407     0.317580                 0.340575
# min                     0.000000     0.000000                 0.000000
# 25%                     0.000000     0.000000                 1.000000
# 50%                     0.000000     0.000000                 1.000000
# 75%                     0.000000     0.000000                 1.000000
# max                     1.000000     1.000000                 1.000000
#
#             Gender  Scholarship holder  Age at enrollment  \
# count  3630.000000         3630.000000        3630.000000
# mean      0.344077            0.266942          23.461157
# std       0.475132            0.442423           7.827994
# min       0.000000            0.000000          17.000000
# 25%       0.000000            0.000000          19.000000
# 50%       0.000000            0.000000          20.000000
# 75%       1.000000            1.000000          25.000000
# max       1.000000            1.000000          70.000000
#
#        Curricular units 1st sem (approved)  Curricular units 1st sem (grade)  \
# count                          3630.000000                       3630.000000
# mean                              4.791460                         10.534860
# std                               3.237845                          5.057694
# min                               0.000000                          0.000000
# 25%                               3.000000                         11.000000
# 50%                               5.000000                         12.341429
# 75%                               6.000000                         13.500000
# max                              26.000000                         18.875000
#
#        Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# count                          3630.000000                       3630.000000
# mean                              4.518457                         10.036155
# std                               3.162376                          5.481742
# min                               0.000000                          0.000000
# 25%                               2.000000                         10.517857
# 50%                               5.000000                         12.333333
# 75%                               6.000000                         13.500000
# max                              20.000000                         18.571429
#
#        Curricular units 2nd sem (without evaluations)       Target
# count                                     3630.000000  3630.000000
# mean                                         0.142149     0.608540
# std                                          0.747670     0.488144
# min                                          0.000000     0.000000
# 25%                                          0.000000     0.000000
# 50%                                          0.000000     1.000000
# 75%                                          0.000000     1.000000
# max                                         12.000000     1.000000

# %%
# Target Variable Distribution
target_col = "Target"

print(df[target_col].value_counts())
# Out:
# Target
# 1    2209
# 0    1421
# Name: count, dtype: int64

# %%
# Target Variable Distribution (Percentage)
print(df[target_col].value_counts(normalize=True) * 100)
# Out:
# Target
# 1    60.853994
# 0    39.146006
# Name: proportion, dtype: float64

# %%
# Visualizing Target Distribution
plt.figure(figsize=(4, 3))
sns.countplot(x='Target', data=df, palette='viridis')
plt.title('Distribution of Target (Student Outcome)')
plt.show()

print(df['Target'].value_counts())
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6176\2957622617.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Target', data=df, palette='viridis')
# Target
# 1    2209
# 0    1421
# Name: count, dtype: int64

# %%
# Top 20 Features correlation with target
plt.figure(figsize=(10, 10))
top_corr = df.corr(numeric_only=True)[target_col].sort_values(ascending=False).head(20)
sns.heatmap(df[top_corr.index].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Top Features Correlated with Target')
plt.show()
# Out:
# c:\Python311\Lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# correlations only among numeric columns and numeric target
corr = df.corr(numeric_only=True)[target_col].sort_values(ascending=False)

# drop self-correlation entry
corr = corr.drop(target_col)

plt.figure(figsize=(5,7))
sns.barplot(x=corr.values, y=corr.index)
plt.title("Correlation of Features with Target (numeric)")
plt.show()

corr
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# Curricular units 2nd sem (approved)               0.653995
# Curricular units 2nd sem (grade)                  0.605350
# Curricular units 1st sem (approved)               0.554881
# Curricular units 1st sem (grade)                  0.519927
# Tuition fees up to date                           0.442138
# Scholarship holder                                0.313018
# Admission grade                                   0.128058
# Displaced                                         0.126113
# Previous qualification (grade)                    0.109464
# Daytime/evening attendance\t                      0.084496
# Educational special needs                        -0.007254
# Previous qualification                           -0.062323
# Marital status                                   -0.100479
# Curricular units 2nd sem (without evaluations)   -0.102687
# Gender                                           -0.251955
# Debtor                                           -0.267207
# Age at enrollment                                -0.267229
# Name: Target, dtype: float64

# %%
# Identifying Numerical Columns
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

if "Target" in numerical_cols:
    numerical_cols.remove("Target")

# %%
# Histograms for Numerical Features
df[numerical_cols].hist(figsize=(18,14), bins=30)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6176\3434612830.py:3: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Outlier Detection using IQR
outlier_summary = {}

for col in numerical_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower) | (df[col] > upper)].shape[0]
    outlier_summary[col] = outliers

pd.DataFrame.from_dict(outlier_summary, orient="index", columns=["Outlier_Count"])\
  .sort_values(by="Outlier_Count", ascending=False)
# Out:
#                                                 Outlier_Count
# Curricular units 2nd sem (grade)                          803
# Curricular units 1st sem (grade)                          652
# Previous qualification                                    611
# Tuition fees up to date                                   486
# Marital status                                            431
# Debtor                                                    413
# Daytime/evening attendance\t                              408
# Age at enrollment                                         389
# Curricular units 2nd sem (without evaluations)            214
# Curricular units 1st sem (approved)                       165
# Previous qualification (grade)                            146
# Admission grade                                            71
# Curricular units 2nd sem (approved)                        44
# Educational special needs                                  40
# Displaced                                                   0
# Gender                                                      0
# Scholarship holder                                          0

# %%
# Distribution Plots for Selected Numerical Features
dist_cols = ['Previous qualification (grade)', 'Admission grade', 'Age at enrollment']

plt.figure(figsize=(20, 5))
for i, col in enumerate(dist_cols, 1):
    plt.subplot(1, 3, i)
    sns.histplot(df[col], kde=True, color='skyblue')
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()
